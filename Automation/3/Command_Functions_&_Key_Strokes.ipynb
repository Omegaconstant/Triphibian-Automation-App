# %% [markdown]
# <html lang="en" dir="ltr">
# <heading>
#   <h5>3b. Given that there are a few functions like the above like pitchUp, pitchDown, rollLeft, rollRight, yawLeft, yawRight, Thrust, Stop, etc. Fill in the code below, in as many ways as possible, to run a particular function on a particular key press. Which is the best method? NOTE: knowledge of pynput is NOT needed. Just assume that calling on_press(key) runs the corresponding function. Eg: on_press(left) should call rollLeft()</h5>
#     <img src="https://raw.githubusercontent.com/Omegaconstant/Triphibian-Automation-App/main/Automation/3/3b.png" alt="Free Body Diagram">
# </heading>
# <hr size="2" noshade="True">
#
# <body>
#   <p>The following Code goes as follows :
#     <br>
#     <ol>
#       <li>1stly import Necessary Modules.</li>
#       <li>Define set() SIGNAL with all possible keystrokes we are gonna consider: basically alphanumeric keys from '0' to '9'.
#       <br>Another set() KEY has been declared to store currently active key. This has been done to store multiple keycodes, if corresponding keys are hold simultaneously.
#       <br />
#       Dummy numerical variable count & list[] keys have been declared to temporarily store a particular active key stroke before writing into a file 'log.txt'.This has been done so that with a sudden close of the system we don't loose the history of active keys pressed.By active it means any key '0' to '9'+Key.esc .
#       </li>
#       <li>Now declare the Command functions using motor-mixing algorithm. Function Static() does nothing, only returns true; only have been added so that no. of Command Functions become 10 :)Anyways it doent take much space.
#       </li>
#       <li>Now comes the crucial part.
#       <br>Address global variable count & keys
#       <br /> Add any keycode to KEY if it is in set SIGNAL.Again this has been done to keep in check of multiple key presses so that multiple functions can be called simultaneously. U may notice a Function called on_release just before the code ends. It basically removes the key once you release an active key.
#       <br />Now if Key.esc is pressed stop the listener.
#       <br>Now if the keycode is '5' & it is in set KEY, then
#       <ul>
#         <li>Call Static()</li>
#         <li>Store keycode in variable Key</li>
#         <li>Append that to list keys</li>
#         <li>count ++ </li>
#         <li>Now count >= 1 ## Instead we can also do count >= 10, which will append the currently active keys to file log.txt in a group of 10 entries</li>
#         <li>Call function write_file with input keys, which will append current key to log.txt file</li>
#         <li>Print the active key pressed.</li>
#       </ul>
#       Similarly do for other command functions as well
#           <ul>
#               <li>2 for pitchDown(), 8 for pitchUp()</li>
#       <li>4 for rollLeft(), 6 for rollRight()</li>
#       <li>1 for ThrustDown(), 9 for ThrustUp()</li>
#       <li>3,7 yawLeft() & yawRight() respectively</li>
#       <li>0 for Stop()
#           </ul>
#     </li>
#     <li>Now we have already a blank file log.txt.With write_file function open it in append mode & add the currently active key in with removing '' & add a '\n'.</li>
#     <li>on_release has been discussed earlier. In exception block just pass without doing anything.</li>
#     <li>Now with on_press & on_release join the listener.</li>
#     </ol>
#     The thing is this code can call multiple functions simultaneously with multiple simultaneous active key press.If we declare everything with only if separated Call of function & suppose we press '1' & '2' simultaneously, it would have taken only the input which was clicked 1st. But this is more interactve & a better method.
#   </p>
# </body>
# </html>

# %%
##  Import required Module

from typing import List  # typing.List Module
from pynput import keyboard  # pynput.keyboard Module


##  Required Global Variables

# The key signal
SIGNAL = {keyboard.KeyCode.from_char('0'), keyboard.KeyCode.from_char('1'),keyboard.KeyCode.from_char('2'),keyboard.KeyCode.from_char('3'),keyboard.KeyCode.from_char('4'),keyboard.KeyCode.from_char('5'),keyboard.KeyCode.from_char('6'),keyboard.KeyCode.from_char('7'),keyboard.KeyCode.from_char('8'),keyboard.KeyCode.from_char('9')}

# The currently active keys
KEY = set()

# A Dummy Variable
count = 0

# The running keys
keys = []


##  The Command Functions
def pitchUp():
    # Code Block for pitchUp
    return True

def pitchDown():
    # Code Block for pitchDown
    return True

def rollLeft():
    # Code Block for rollLeft
    return True

def rollRight():
    # Code Block for rollRight
    return True

def yawLeft():
    # Code Block for yawLeft
    return True

def yawRight():
    # Code Block for yawRight
    return True
    
def ThrustUp():
    # Code Block for ThrustUp
    return True

def ThrustDown():
    # Code Block for ThrustDown
    return True

def Static():
    # Code Block for Static
    # Static() does nothing in practice
    # Only returns True
    return True

def Stop():
    # Code Block for Stop
    return True


##  The on_press Function
def on_press(key) :
    global keys,count
    if key in SIGNAL :
        KEY.add(key)
    if key == keyboard.Key.esc :
        listener.stop()
    if (keyboard.KeyCode.from_char('5') in KEY) :
        Static()
        Key = keyboard.KeyCode.from_char('5')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('2') in KEY) :
        pitchDown()
        Key = keyboard.KeyCode.from_char('2')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('8') in KEY) :
        pitchUp()
        Key = keyboard.KeyCode.from_char('8')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('4') in KEY) :
        rollLeft()
        Key = keyboard.KeyCode.from_char('4')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('6') in KEY) :
        rollRight()
        Key = keyboard.KeyCode.from_char('6')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('1') in KEY) :
        ThrustDown()
        Key = keyboard.KeyCode.from_char('1')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('9') in KEY) :
        ThrustUp()
        Key = keyboard.KeyCode.from_char('9')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('3') in KEY) :
        yawLeft()
        Key = keyboard.KeyCode.from_char('3')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('7') in KEY) :
        yawRight()
        Key = keyboard.KeyCode.from_char('7')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
    if (keyboard.KeyCode.from_char('0') in KEY) :
        Stop()
        Key = keyboard.KeyCode.from_char('0')
        keys.append(Key)
        count+=1
        if count >= 1 :
            write_file(keys)
            count = 0
            keys = [] 
        print("{0} has beeen pressed".format(Key))
        listener.stop()

        
## The write_file Function
def write_file(keys):
    with open("log.txt","a") as file :
        for key in keys :
            k = str(key).replace("'","")
            file.write(k)
            file.write('\n')

            
## The on_release Function
def on_release(key):
    try:
        KEY.remove(key)
    except KeyError:
        pass

    
## Call the Listener thread
with keyboard.Listener(on_press=on_press, on_release=on_release) as listener:
    listener.join()
# Out:
# '1' has beeen pressed
# '2' has beeen pressed
# '3' has beeen pressed
# '4' has beeen pressed
# '5' has beeen pressed
# '6' has beeen pressed
# '7' has beeen pressed
# '8' has beeen pressed
# '9' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '1' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# '2' has beeen pressed
# '1' has beeen pressed
# '3' has beeen pressed
# ...

# %% [markdown]
# <html lang="en" dir="ltr">
# <heading>
#   <h5>Documentary References :</h5>
# </heading>
# <hr size="2" noshade="True">
#
# <body>
#   <p>
#     <ol>
#       <li><a href="https://www.youtube.com/watch?v=cdfuuyXzuyc">Python Keylogger Tutorial-Windows</a></li>
#       <li><a href="https://github.com/moses-palmer/pynput/issues/20">How to listen Key combination?</a></li>
#       <li><a href="https://stackoverflow.com/questions/54457363/pynput-listener-doesnt-allow-if-statements-with-alphanumeric-characters">pynput listener doesn't allow if statements with alphanumeric characters</a></li>
#       <li><a href="https://pynput.readthedocs.io/en/latest/keyboard.html">pynput python package documentation</a></li>
#     </ol>
#     </p>
# </body>
# </html>
